# %% [markdown]
# SNR Measurement for Field Strength Comparisons
# ===============================================
#
# This notebook is a self contained workflow for analyzing relaxation and SNR measurements.

# %% [markdown]
# Change plotting settings here for outer types of output (e.g. `inline`)

# %%
# %matplotlib notebook

# %% [markdown]
# Functions for labeling and analyzing images

# %%
import os
import dicom

import numpy as np
import matplotlib.pyplot as plt

from skimage.filters import threshold_otsu
from skimage.segmentation import clear_border
from skimage.measure import label, moments
from skimage.morphology import closing, erosion, square
from scipy.signal import medfilt
from scipy.optimize import fmin

def display_dicom(dcm,colormap='gray',colorbar=True):
    fig, ax = plt.subplots(ncols=1, nrows=1)
    cax = ax.imshow(dcm.pixel_array,cmap=plt.get_cmap(colormap))

    if colorbar:
        fig.colorbar(cax)

def parse_dicom_tree(path):
    dcms = dict()
    for fn in os.listdir(path):
        ffn = os.path.join(path,fn)
        if os.path.isfile(ffn):
            try:
                ds = dicom.read_file(ffn)
                snum = ds.SeriesNumber
                if not snum in dcms:
                    dcms[snum] = list()
                dcms[snum].append(ds)
                
            except dicom.errors.InvalidDicomError:
                print("Skipping " + ffn + ", not a DICOM file")
    return dcms

def print_dicom_summary(dcms):
    series = sorted(dcms.keys())
    for s in series:
        print (str(dcms[s][0].SeriesNumber) + '\t' + str(len(dcms[s])) + '\t' + dcms[s][0].SeriesDescription)
        
def label_image(image, threshold_sensitivity=0.1,erosion_size=4):
    # apply threshold
    thresh = threshold_otsu(image)
    bw = closing(image > threshold_sensitivity*thresh, square(3))
    bw = erosion(bw, square(erosion_size))

    # remove artifacts connected to image border
    cleared = bw.copy()
    clear_border(cleared)

    # label image regions
    label_image = label(cleared)
    borders = np.logical_xor(bw, cleared)
    label_image[borders] = 0
    
    return label_image

def display_labels(label_image):
    fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(6, 6))
    ax.imshow(label_image,cmap=plt.cm.gray)

    for l in range(1,np.max(label_image)+1):
        ml = (label_image == l)
        m = moments(ml.astype(np.double))
        c = m[0, 1] / m[0, 0], m[1, 0] / m[0, 0]
        ax.text(c[1], c[0],str(l),color='red')
        
def calc_flip_angle_map(dcm1,dcm2):
    if dcm1.FlipAngle > dcm2.FlipAngle:
        im_low = dcm2.pixel_array
        im_high = dcm1.pixel_array
        flip_angle_low = dcm2.FlipAngle
        flip_angle_high = dcm1.FlipAngle
    else:
        im_low = dcm1.pixel_array
        im_high = dcm2.pixel_array
        flip_angle_low = dcm1.FlipAngle
        flip_angle_high = dcm2.FlipAngle

    if flip_angle_high != 2*flip_angle_low:
        raise Exception('Low flip angle is not half of high flip angle')
    
    im_low = medfilt(im_low.astype(np.double),5)
    im_high = medfilt(im_high.astype(np.double),5)

    q = im_high/(2*(im_low+np.finfo(np.double).eps))
    q = np.clip(q,-1, 1);
    fa = np.arccos(q)*(180/np.pi);    
    
    #q = im_low/(im_high+np.finfo(np.double).eps)
    #q = np.clip(q,-1, 1);
    #fa = np.arcsin(q)*(180/np.pi);    

    fa = fa/flip_angle_low
    return fa

def get_label_mean(img,label_image,labels=[]):
    if not labels:
        labels = range(np.min(label_image),np.max(label_image)+1)
    
    means = list()
    for l in labels:
        m = (label_image == l).astype(np.double)
        s = np.sum(m*img)/np.sum(m)
        means.append(s)
        
    return means

def get_IR_data(dcms, label_image, labels=[]):
    if not labels:
        labels = range(np.min(label_image),np.max(label_image)+1)

    images = len(dcms)
    labs = len(labels)

    TIs = np.zeros((images,),dtype=np.double)
    signal = np.zeros((images,labs),dtype=np.double)

    for idx, im in enumerate(dcms):
        means = get_label_mean(im.pixel_array,label_image,labels=labels)
        signal[idx,:] = np.array(means)
        TIs[idx] = im.InversionTime
        
    idx = [i[0] for i in sorted(enumerate(TIs), key=lambda x:x[1])]  
    signal = signal[idx,:]
    TIs = TIs[idx]
    
    return TIs, signal

def fit_t1_mag_IR(TIs, IRSignal):
    #Doing 3 parameters fit
    # S = A - B exp(-TI./T1star)
    
    if len(IRSignal.shape) > 1:
        curves = IRSignal.shape[1]
    else:
        curves = 1
    
    fits = list()
    for c in range(0,curves):
        #First get a starting estimate
        s = IRSignal[:,c]
        ss = sorted(enumerate(abs(s)), key=lambda x: x[1])
        if ss[0][0] == 0: 
            T1star = np.min(TIs)/np.log(2);
        else:
            tmp = ss[0:2]
            if tmp[0][0] > tmp[1][0]:
                tmp = [tmp[1], tmp[0]]
            slope = (tmp[1][1] + tmp[0][1])/(TIs[tmp[1][0]]-TIs[tmp[0][0]])
            T1star = (tmp[0][1]/slope + TIs[tmp[0][0]])/np.log(2)
        

        #Next let's do the fit with scipy.optimize.fmin (simplex)
        Ainit = np.max(np.abs(s))
        x0 = [Ainit, 2*Ainit, T1star] 
        costfcn = lambda x: np.sum((np.abs(x[0]-x[1]*np.exp(-TIs/x[2]))-s)**2)
        x = fmin(costfcn,x0=x0,disp=False)
        fits.append(x)
        
    return fits

def get_SE_data(dcms, label_image, labels=[]):
    if not labels:
        labels = range(np.min(label_image),np.max(label_image)+1)

    images = len(dcms)
    labs = len(labels)

    TEs = np.zeros((images,),dtype=np.double)
    signal = np.zeros((images,labs),dtype=np.double)

    for idx, im in enumerate(dcms):
        means = get_label_mean(im.pixel_array,label_image,labels=labels)
        signal[idx,:] = np.array(means)
        TEs[idx] = im.EchoTime
        
    idx = [i[0] for i in sorted(enumerate(TEs), key=lambda x:x[1])]  
    signal = signal[idx,:]
    TEs = TEs[idx]
    
    return TEs, signal

def fit_t2_SE(TEs,signal):
    #Doing s parameters fit
    # S = A exp(-TE./T2)
    
    if len(IRSignal.shape) > 1:
        curves = IRSignal.shape[1]
    else:
        curves = 1
    
    fits = list()
    for c in range(0,curves):
        #First get a starting estimate
        s = signal[:,c]
        y = np.log(np.abs(s))
        x = TEs;
        b = np.sum((x - np.mean(x))*(y - np.mean(y)))/np.sum((x - np.mean(x))**2)
        a = np.mean(y) - b*np.mean(x)
        x0 = [np.exp(a), -1/b]

        costfcn = lambda x: np.sum((np.abs(x[0]*np.exp(-TEs/x[1]))-s)**2)
        x = fmin(costfcn,x0=x0,disp=False)
        fits.append(x)
    return fits

def imlist_to_pixel_array(imgs):
    img_size = imgs[0].pixel_array.shape
    img_array = np.zeros((len(imgs), img_size[0],img_size[1]))
    for idx, i in enumerate(imgs):
        img_array[idx,:,:] = i.pixel_array
    return img_array

# %% [markdown]
# Reading Images
# ===============
#
# The analysis workflow starts with parsing all the dicom images in a given folder. The list below should give an overview of serries names and the number of images in each series.

# %%
d = parse_dicom_tree('/home/hansenms/data/PANDA/NIH_PANDA/DAY1_DICOMS')
print_dicom_summary(d)
# Out:
# 1	6	se_15b130
# 2	1	se_15b130
# 3	6	se_15b130
# 4	1	se_15b130
# 5	6	se_15b130
# 6	1	se_15b130
# 7	1	CV_Gadgetron__GT
# 8	1	CV_Gadgetron__GT_SNR_MAP
# 9	1	CV_Gadgetron__GT
# 10	1	CV_Gadgetron__GT_SNR_MAP
# 11	1	CV_Gadgetron__GT_Noise_SD_Plot
# 12	1	CV_Gadgetron__GT
# 13	1	CV_Gadgetron__GT_SNR_MAP
# 14	1	CV_Gadgetron__GT_Noise_SD_Plot
# 15	8	gre multiecho
# 16	8	gre multiecho
# 17	1	CV_Gadgetron__GT
# 18	1	CV_Gadgetron__GT_SNR_MAP
# 19	1	CV_Gadgetron__GT_Noise_SD_Plot
# 20	9	trufi_loc_multi_iPAT
# 21	1	MiniFLASH_b1_map_35__GT
# 22	1	MiniFLASH_b1_map_35__GT_SNR_MAP
# 23	1	MiniFLASH_pk__GT
# 24	1	MiniFLASH_pk__GT_SNR_MAP
# 25	1	test__GT
# 26	1	test__GT_SNR_MAP
# 27	1	CV_Gadgetron__GT
# 28	1	CV_Gadgetron__GT_SNR_MAP
# 29	9	trufi_loc_multi_iPAT
# 30	1	CV_Gadgetron__GT
# 31	1	CV_Gadgetron__GT_SNR_MAP
# 32	1	CV_Gadgetron__GT_Noise_SD_Plot
# 33	1	test__GT
# 34	1	test__GT_SNR_MAP
# 35	1	test__GT_Noise_SD_Plot
# 36	1	MiniFLASH_pk_b1_120 TRA__GT
# 37	1	MiniFLASH_pk_b1_120 TRA__GT_SNR_MAP
# 38	1	MiniFLASH_pk_b1_120 TRA__GT_Noise_SD_Plot
# 39	1	MiniFLASH_pk_b1_60 TRA__GT
# 40	1	MiniFLASH_pk_b1_60 TRA__GT_SNR_MAP
# 41	1	MiniFLASH_pk_b1_60 TRA__GT_Noise_SD_Plot
# 42	1	MiniFLASH_pk_b1_120 COR__GT
# 43	1	MiniFLASH_pk_b1_120 COR__GT_SNR_MAP
# 44	1	MiniFLASH_pk_b1_120 COR__GT_Noise_SD_Plot
# 45	1	MiniFLASH_pk_b1_60 COR__GT
# 46	1	MiniFLASH_pk_b1_60 COR__GT_SNR_MAP
# 47	1	MiniFLASH_pk_b1_60 COR__GT_Noise_SD_Plot
# 48	1	MiniFLASH_pk_b1_120 SAG__GT
# 49	1	MiniFLASH_pk_b1_120 SAG__GT_SNR_MAP
# 50	1	MiniFLASH_pk_b1_120 SAG__GT_Noise_SD_Plot
# 51	1	MiniFLASH_pk_b1_60 SAG__GT
# 52	1	MiniFLASH_pk_b1_60 SAG__GT_SNR_MAP
# 53	1	MiniFLASH_pk_b1_60 SAG__GT_Noise_SD_Plot
# 54	8	gre 8echo t2star
# 55	4	gre 4echo fw
# 56	1	rf_field
# 57	1	rf_field
# 58	1	rf_field
# 59	1	rf_field
# 60	1	rf_field
# 61	1	rf_field
# 62	1	rf_field
# 63	1	rf_field
# 64	1	rf_field
# 65	9	trufi_loc_multi_iPAT
# 66	4	gre 4echo fw
# 67	1	IR_MiniFLASH_pk_TI10__GT
# 68	1	IR_MiniFLASH_pk_TI10__GT_SNR_MAP
# 69	1	IR_MiniFLASH_pk_TI10__GT_Noise_SD_Plot
# 70	1	IR_MiniFLASH_pk_TI20__GT
# 71	1	IR_MiniFLASH_pk_TI20__GT_SNR_MAP
# 72	1	IR_MiniFLASH_pk_TI20__GT_Noise_SD_Plot
# 73	1	IR_MiniFLASH_pk_TI40__GT
# 74	1	IR_MiniFLASH_pk_TI40__GT_SNR_MAP
# 75	1	IR_MiniFLASH_pk_TI40__GT_Noise_SD_Plot
# 76	1	IR_MiniFLASH_pk_TI80__GT
# 77	1	IR_MiniFLASH_pk_TI80__GT_SNR_MAP
# 78	1	IR_MiniFLASH_pk_TI80__GT_Noise_SD_Plot
# 79	1	IR_MiniFLASH_pk_TI160__GT
# 80	1	IR_MiniFLASH_pk_TI160__GT_SNR_MAP
# 81	1	IR_MiniFLASH_pk_TI160__GT_Noise_SD_Plot
# 82	1	IR_MiniFLASH_pk_TI320__GT
# 83	1	IR_MiniFLASH_pk_TI320__GT_SNR_MAP
# 84	1	IR_MiniFLASH_pk_TI320__GT_Noise_SD_Plot
# 85	1	IR_MiniFLASH_pk_TI640__GT
# 86	1	IR_MiniFLASH_pk_TI640__GT_SNR_MAP
# 87	1	IR_MiniFLASH_pk_TI640__GT_Noise_SD_Plot
# 88	1	IR_MiniFLASH_pk_TI1300__GT
# 89	1	IR_MiniFLASH_pk_TI1300__GT_SNR_MAP
# 90	1	IR_MiniFLASH_pk_TI1300__GT_Noise_SD_Plot
# 91	1	IR_MiniFLASH_pk_TI2600__GT
# 92	1	IR_MiniFLASH_pk_TI2600__GT_SNR_MAP
# 93	1	IR_MiniFLASH_pk_TI2600__GT_Noise_SD_Plot
# 94	1	se_msh_TE10__GT
# 95	1	se_msh_TE10__GT_SNR_MAP
# 96	1	se_msh_TE10__GT_Noise_SD_Plot
# 97	1	se_msh_TE20__GT
# 98	1	se_msh_TE20__GT_SNR_MAP
# 99	57	PhoenixZIPReport
# 100	1	se_msh_TE20__GT_Noise_SD_Plot
# 101	1	se_msh_TE40__GT
# 102	1	se_msh_TE40__GT_SNR_MAP
# 103	1	se_msh_TE40__GT_Noise_SD_Plot
# 104	1	se_msh_TE80__GT
# 105	1	se_msh_TE80__GT_SNR_MAP
# 106	1	se_msh_TE80__GT_Noise_SD_Plot
# 107	1	se_msh_TE160__GT
# 108	1	se_msh_TE160__GT_SNR_MAP
# 109	1	se_msh_TE160__GT_Noise_SD_Plot
# 110	1	se_msh_TE320__GT
# 111	1	se_msh_TE320__GT_SNR_MAP
# 112	1	se_msh_TE320__GT_Noise_SD_Plot
# 113	1	se_msh_TE640__GT
# 114	1	se_msh_TE640__GT_SNR_MAP
# 115	1	se_msh_TE640__GT_Noise_SD_Plot
# 116	1	test__GT
# 117	1	test__GT_SNR_MAP
# 118	1	test__GT_Noise_SD_Plot
# 119	8	T1Map_LongT1
# 120	8	T1Map_LongT1_MOCO
# 121	1	T1Map_LongT1_MOCO_T1
# 122	9	T1Map_ShortT1
# 123	9	T1Map_ShortT1_MOCO
# 124	1	T1Map_ShortT1_MOCO_T1
# 125	3	T2Map_TrueFISP
# 126	3	T2Map_TrueFISP_MOCO
# 127	2	T2Map_TrueFISP_MOCO_T2

# %% [markdown]
# Classification of Image Series
# ===============================
#
# Based on the list above, identify

# %%
fa_data_TRA = [37,40] #flip angle measurements
fa_data_COR = [43,46] #flip angle measurements
fa_data_SAG = [49,52] #flip angle measurements

fa_data = fa_data_SAG

# %%
# Initial overview image
im = d[fa_data[0]][0]
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(6, 6))
ax.imshow(im.pixel_array,cmap=plt.cm.gray)
# Out:
# <img src="data:image/png;base64,...">

# %%
#Now label the data
im = d[fa_data[0]][0]
labels = label_image(im.pixel_array,threshold_sensitivity=0.5)

labels = np.zeros(labels.shape,dtype=labels.dtype)
labels[45:90,45:90] = 1
display_labels(labels)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Regions of Interest
# ====================
#
# Based on automatic labeling above, select the tubes (phantoms) you are interested in analyzing

# %%
tubes = [1]

# %%
# Flip angle map
fa = calc_flip_angle_map(d[fa_data[0]][0],d[fa_data[1]][0])
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(6, 6))
img = ax.imshow(fa,cmap=plt.cm.jet)
fig.colorbar(img)
# Out:
# <img src="data:image/png;base64,...">

# %%
#Flip angles in tubes
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(6, 6))
ax.plot(fa[:,64])
# Out:
# <img src="data:image/png;base64,...">

# %%
snr_img = d[fa_data[0]][0]
snr_pixels = snr_img.pixel_array/10.0

# %%
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(6, 6))
ax.plot(snr_pixels[:,64])
# Out:
# <img src="data:image/png;base64,...">

# %%
1.5/0.55
# Out:
# 2.727272727272727

# %%
2.7/4.1
# Out:
# 0.6585365853658538

# %%
SNR_RATIO = 409.0/94.0
POLARIZATION_RATIO = 1.5/0.55

# %%
SNR_RATIO
# Out:
# 4.351063829787234

# %%
SNR_RATIO/POLARIZATION_RATIO
# Out:
# 1.5953900709219861
