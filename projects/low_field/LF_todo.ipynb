# %% [markdown]
# Experiments:
# --------------
#
# * “Acceptance Testing”
# * B0 mapping
# * B1 mapping (dual flip angle sequence, good TBP = 10 for good slice profile)
# * Coil coupling test
# * Test shims
# * GIRF measurement
#
#
# Phantoms:
# -----------
#
# * T1MES and NIST
# * Long T1 and T2 mapping @ 0.55T and 1.5T
# * Myomaps T1 and T2 mapping
# * Calculate SNR ratio
# * Meat (and blood?)
# * Long T1 and T2 mapping @ 0.55T and 1.5T
# * Myomaps T1 and T2 mapping
# * Need T1, T2 mapping
# * Fat/water separation
#
#
# Heating test
# ---------------
#
#
# Needs:
# --------
#
# * Compile Sequences
#     * CV
#     * CV multiecho:
#     * CV epi
#     * T1/T2 mapping (myomaps)
#     * BEAT_IRTTT
#     * Spiral bSSFP
#     * B0 mapping
#     * B1 mapping
#     * GIRF sequence
#     * Passive guidewire visualization sequences (?)
#
# Compile ICE:
# ---------------
#
# * IceGadgetron
# * GIRF calculation
# * Gadgetron fat/water reconstruction
#
#
# Devices:
# ----------
#
# * Nitrex (145cm and 180cm)
# * Glidewire (150cm and 260cm)
# * Nitinol Rods
# * Active guidewire (?)
# * Catheters (Arrow BWEC)
# * Pacemakers, defrilbrilator (artifacts)
#
# More equipment:
# ------------------
# * Gadgetron laptopand switch
# * USB sticks/hard drives
#
#
# Questions:
# Siemens
# Will we have WIP 1041
# Can we run sequences over night
# Is there guest wifi?
# Where can we mix phantom / is there distilled water?
#
#
# Can Helmut Stark make the phantom
#
#
# Robert
# pacemakers/devices to bring
# Cath fab personnel
