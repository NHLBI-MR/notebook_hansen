# %%
using PyPlot
# Out:
# INFO: Precompiling module PyPlot.

# %%
x = linspace(0,2*pi,50); 
y = sin(x)
plot(x, y)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff5f9ae5fd0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7ff6316a2e48>
